# %% [markdown]
# ### data ingestion

# %%
### document structure

from langchain_core.documents import Document

# %%
doc = Document(
    page_content = "this is main page content , the first important element in documents datastructure",
    metadata = {
        "source" : "example.txt",
        "pages" : 1,
        "author" : "Iqra Abid"
    }
)

doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Iqra Abid'}, page_content='this is main page content , the first important element in documents datastructure')

# %%
#create a simple txt file

import os
os.makedirs("../data/text_files" , exist_ok = True)

# %%
sample_texts = {
    "../data/text_files/AIEngineer_intro.txt" : """
    An AI Engineer designs, builds, and deploys applications powered by artificial intelligence.
They use programming languages like Python and work with machine learning and deep learning models.
AI Engineers integrate technologies such as LLMs, RAG, vector databases, and APIs into real-world applications.
They preprocess data, train or fine-tune models, and optimize AI systems for accuracy and performance.
They collaborate with software developers and data scientists to create scalable AI solutions.
AI Engineers continuously test, monitor, and improve AI applications to ensure reliability, efficiency, and a good user experience.
    """
    ,
    "../data/text_files/pythonintro.txt" : """
    blah 
    blah
    """
}

# %%
for filepath,content in sample_texts.items():
    with open(filepath, 'w' , encoding="utf-8") as f:
        f.write(content)
print("sample text files created")
# Out:
# sample text files created

# %%
#text loader
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("../data/text_files/pythonintro.txt", encoding= "utf-8")
loader

# %%
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/pythonintro.txt'}, page_content='\n    blah \n    blah\n    ')]

# %%
### directory loader

from langchain_community.document_loaders import DirectoryLoader

##load all the text files from thw directory

dir_loader = DirectoryLoader(
    "../data/text_files",
    glob = "**/*.txt" , #pattern to match files
    loader_cls = TextLoader, #loader class to use
    loader_kwargs = {'encoding': 'utf-8'},
    show_progress = False
)

documents = dir_loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\AIEngineer_intro.txt'}, page_content='\n    An AI Engineer designs, builds, and deploys applications powered by artificial intelligence.\nThey use programming languages like Python and work with machine learning and deep learning models.\nAI Engineers integrate technologies such as LLMs, RAG, vector databases, and APIs into real-world applications.\nThey preprocess data, train or fine-tune models, and optimize AI systems for accuracy and performance.\nThey collaborate with software developers and data scientists to create scalable AI solutions.\nAI Engineers continuously test, monitor, and improve AI applications to ensure reliability, efficiency, and a good user experience.\n    '), Document(metadata={'source': '..\\data\\text_files\\pythonintro.txt'}, page_content='\n    blah \n    blah\n    ')]

# %%
#pdf loader


from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

dir_loader = DirectoryLoader(
    "../data/pdf",
    glob = "**/*.pdf" , #pattern to match files
    loader_cls = PyMuPDFLoader, #loader class to use
    show_progress = False
)

pdf_documents = dir_loader.load()
print(pdf_documents)
# Out:
# [Document(metadata={'producer': '', 'creator': 'WPS Docs', 'creationdate': '2026-07-18T02:15:42-07:00', 'source': '..\\data\\pdf\\Iqra Abid cover letter.pdf', 'file_path': '..\\data\\pdf\\Iqra Abid cover letter.pdf', 'total_pages': 1, 'format': 'PDF 1.7', 'title': '', 'author': 'PEM', 'subject': '', 'keywords': '', 'moddate': '2026-07-18T02:15:42-07:00', 'trapped': '', 'modDate': "D:20260718021542-07'00'", 'creationDate': "D:20260718021542-07'00'", 'page': 0}, page_content='Iqra Abid\nKarachi, Pakistan\n0327-2933893\niqra65952@gmail.com\n18 July 2026\nDear Hiring Manager,\nMy name is Iqra Abid, and I am currently pursuing a Bachelor of Engineering in Computer Systems\nEngineering at NED University of Engineering & Technology. I am passionate about Artificial Intelligence,\nMachine Learning, and software development, and I am looking for an opportunity to begin my professional\ncareer through a paid internship where I can learn, contribute, and grow.\nThroughout my academic journey, I
# ...

# %%
type(pdf_documents[1])
# Out:
# langchain_core.documents.base.Document
